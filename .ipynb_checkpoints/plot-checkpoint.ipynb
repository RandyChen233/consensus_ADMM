# %%
from functools import reduce
from itertools import cycle
from operator import mul
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np
# %load_ext autoreload
# %autoreload 2
from util import split_agents, compute_pairwise_distance

# %%
import dpilqr
import util

# %% [markdown]
# #### 3-D trajectory of regular ADMM

# %%
import matplotlib.font_manager

# %%
trajectory_data = np.load("ADMM_BVC_convex_5.npz")

# %%
trajectory_data
# Out:
# NpzFile 'ADMM_BVC_convex_5.npz' with keys: X_full, obj_trj, xr

# %%
X_full = trajectory_data['X_full']
xr = trajectory_data['xr']
obj_trj = trajectory_data['obj_trj']

# %%
X_full[-1]
# Out:
# array([-0.315,  0.539,  1.112,  0.027,  0.028, -0.042, -0.648, -0.717,
#         1.305, -0.029, -0.033,  0.039,  0.919, -0.591,  1.502, -0.022,
#        -0.088,  0.014,  0.805,  0.309,  1.271,  0.225,  0.109, -0.06 ,
#        -0.79 ,  0.455,  1.196, -0.128, -0.004, -0.019])

# %%
xr.T
# Out:
# array([[-0.311,  0.549,  1.109,  0.   ,  0.   ,  0.   , -0.659, -0.73 ,
#          1.323,  0.   ,  0.   ,  0.   ,  0.92 , -0.62 ,  1.516,  0.   ,
#          0.   ,  0.   ,  0.885,  0.343,  1.263,  0.   ,  0.   ,  0.   ,
#         -0.834,  0.457,  1.2  ,  0.   ,  0.   ,  0.   ]])

# %%
dpilqr.distance_to_goal(X_full[-1].flatten(), xr.flatten(), 5, 6, 3)
# Out:
# array([0.011, 0.026, 0.032, 0.087, 0.044])

# %%
obj_trj
# Out:
# array(422.664)

# %%
x_dims = [6,6,6,6,6]

# %%
dpilqr.plot_solve?
# Out:
# Signature:
# dpilqr.plot_solve(
#     X,
#     J,
#     x_goal,
#     x_dims=None,
#     color_agents=False,
#     n_d=2,
#     ax=None,
# )
# Docstring: Plot the resultant trajectory on plt.gcf()
# File:      ~/projects/ICON_lab/dp-ilqr/dpilqr/graphics.py
# Type:      function

# %%
plt.figure(dpi=150)
dpilqr.plot_solve(X_full, float(obj_trj), xr, x_dims, True, 3)
plt.legend(plt.gca().get_children()[1:3], ["Start Position", "Goal Position"]);
plt.gca().set_zticks([0,2.2])
plt.gca().set_xticks([-1.5, 0, 1.5])
plt.gca().set_yticks([-1.5, 0, 1.5])
# plt.gca().grid('off')
plt.savefig('figures/BVC_5_drones', bbox_inches='tight', dpi=300)
# Out:
# /tmp/ipykernel_157/906960868.py:8: UserWarning: constrained_layout not applied because axes sizes collapsed to zero.  Try making figure larger or axes decorations smaller.
#   plt.savefig('figures/BVC_5_drones', bbox_inches='tight', dpi=300)

# %%
compute_pairwise_distance(X_full,x_dims).min()
# Out:
# 0.03893578892936585

# %%
X_full[0]
# Out:
# array([ 0.307, -0.592,  2.174,  0.   ,  0.   ,  0.   , -0.366,  0.7  ,
#         2.1  ,  0.   ,  0.   ,  0.   ,  0.058, -0.108,  1.094,  0.   ,
#         0.   ,  0.   ])
